# %% [markdown]
# ## Final Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project"
# Out:
# /content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project

# %%
# %pip install -q gpflow empyrical

# %%
# !python -m examples.concurent_cpd_quandl 126
# Out:
# Streaming output truncated to the last 5000 lines.
# Skipping already processed window 1411
# Skipping already processed window 1412
# Skipping already processed window 1413
# Skipping already processed window 1414
# Skipping already processed window 1415
# processing windows:  28% 128/461 [01:52<04:13,  1.31batch/s]Processing batch 141/461
# Skipping already processed window 1406
# Skipping already processed window 1407
# Skipping already processed window 1408
# Skipping already processed window 1409
# Skipping already processed window 1410
# Skipping already processed window 1411
# Skipping already processed window 1412
# Skipping already processed window 1413
# Skipping already processed window 1414
# Skipping already processed window 1415
# processing windows:  23% 126/539 [01:51<05:23,  1.28batch/s]Processing batch 139/539
# Skipping already processed window 1386
# Skipping already processed window 1387
# Skipping already processed window 1388
# ...
