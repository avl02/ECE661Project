# %% [markdown]
# ## Final Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project"
# Out:
# /content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project

# %%
# %pip install gpflow empyrical
# Out:
# Collecting gpflow
#   Downloading gpflow-2.9.2-py3-none-any.whl.metadata (13 kB)
# Collecting empyrical
#   Downloading empyrical-0.5.5.tar.gz (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 6.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting check-shapes>=1.0.0 (from gpflow)
#   Downloading check_shapes-1.1.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from gpflow) (1.2.18)
# Requirement already satisfied: multipledispatch>=0.6 in /usr/local/lib/python3.11/dist-packages (from gpflow) (1.0.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from gpflow) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gpflow) (24.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gpflow) (1.13.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from gpflow) (75.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from gpflow) (0.9.0)
# Requirement already satisfied: tensorflow-probability>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability[tf]>=0.12.0->gpflow) (0.25.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from gpflow) (4.12.2)
# Requirement already satisfied: tensorflow>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from gpflow) (2.18.0)
# Requirement already satisfied: pandas>=0.16.1 in /usr/local/lib/python3.11/dist-packages (from empyrical) (2.2.2)
# Requirement already satisfied: pandas-datareader>=0.2 in /usr/local/lib/python3.11/dist-packages (from empyrical) (0.10.0)
# Collecting dropstackframe>=0.1.0 (from check-shapes>=1.0.0->gpflow)
#   Downloading dropstackframe-0.1.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting lark<2.0.0,>=1.1.0 (from check-shapes>=1.0.0->gpflow)
#   Downloading lark-1.2.2-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.1->empyrical) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.1->empyrical) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.16.1->empyrical) (2025.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from pandas-datareader>=0.2->empyrical) (5.3.1)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pandas-datareader>=0.2->empyrical) (2.32.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (4.25.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (3.8.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow>=2.4.0->gpflow) (0.37.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (4.4.2)
# Requirement already satisfied: cloudpickle>=1.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (3.1.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (0.1.9)
# Requirement already satisfied: tf-keras>=2.16 in /usr/local/lib/python3.11/dist-packages (from tensorflow-probability[tf]>=0.12.0->gpflow) (2.18.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow>=2.4.0->gpflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pandas-datareader>=0.2->empyrical) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.4.0->gpflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.4.0->gpflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow>=2.4.0->gpflow) (3.1.3)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.11/dist-packages (from dm-tree->tensorflow-probability>=0.12.0->tensorflow-probability[tf]>=0.12.0->gpflow) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow>=2.4.0->gpflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow>=2.4.0->gpflow) (0.1.2)
# Downloading gpflow-2.9.2-py3-none-any.whl (392 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.9/392.9 kB 30.9 MB/s eta 0:00:00
# Downloading check_shapes-1.1.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 5.1 MB/s eta 0:00:00
# Downloading dropstackframe-0.1.1-py3-none-any.whl (4.6 kB)
# Downloading lark-1.2.2-py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 13.1 MB/s eta 0:00:00
# Building wheels for collected packages: empyrical
#   Building wheel for empyrical (setup.py) ... done
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39753 sha256=74560de66f6224f18533a51b7a9ff44dfdef5a21d57d6b138f03507b1ec30fc1
#   Stored in directory: /root/.cache/pip/wheels/ac/1d/58/a7ae5ef5c8de7c4b769f24c2584f4706564921f031b16b9cb6
# Successfully built empyrical
# Installing collected packages: lark, dropstackframe, check-shapes, empyrical, gpflow
# Successfully installed check-shapes-1.1.1 dropstackframe-0.1.1 empyrical-0.5.5 gpflow-2.9.2 lark-1.2.2

# %%
# !python -m examples.concurent_cpd_quandl 21
# Out:
# Processing batches:   0% 0/4 [00:00<?, ?batch/s]Processing batch 1/4 with 10 tickers
#
# Batch 1 progress:   0% 0/10 [00:00<?, ?ticker/s]2025-04-18 20:47:09.173296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.184296: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.195248    1413 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.201819    1413 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.204840    1415 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.211454    1415 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-18 20:47:09.247392: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.280920: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.280970: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.280979: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.280992: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.280991: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.281018: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-04-18 20:47:09.281040: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.283534    1417 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.294448    1417 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.316889    1412 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.316940    1411 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.316991    1416 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.316991    1410 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.317082    1408 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745009229.317273    1414 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.317253    1409 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745009229.327766    1412 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.327888    1411 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.327905    1416 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.328106    1408 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.328125    1410 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.328290    1409 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# E0000 00:00:1745009229.328306    1414 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# GPU is available: 1 GPU(s) detected
# processing windows:   0% 0/546 [00:00<?, ?batch/s]Processing batch 3/546
# processing windows:   0% 0/536 [00:00<?, ?batch/s]Processing batch 3/536
# I0000 00:00:1745009251.458294    1413 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38128 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009251.458307    1416 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38128 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# processing windows:   0% 0/550 [00:00<?, ?batch/s]Processing batch 3/550
# processing windows:   0% 0/550 [00:00<?, ?batch/s]Processing batch 3/550
# processing windows:   0% 0/549 [00:00<?, ?batch/s]Processing batch 3/549
# I0000 00:00:1745009254.209124    1410 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 36868 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009254.211757    1411 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 36868 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009254.216570    1408 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 36868 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009256.606641    1990 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x1fc0f980
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009256.619023    1991 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x238cf9c0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009258.599131    2265 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x221a16a0
# processing windows:   0% 0/539 [00:00<?, ?batch/s]Processing batch 3/539
# processing windows:   0% 0/547 [00:00<?, ?batch/s]Processing batch 3/547
# processing windows:   0% 0/542 [00:00<?, ?batch/s]Processing batch 3/542
# processing windows:   0% 0/557 [00:00<?, ?batch/s]Processing batch 3/557
# processing windows:   0% 0/536 [00:00<?, ?batch/s]Processing batch 3/536
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009258.704534    2251 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x3fe67310
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009258.728464    2238 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x213bf390
# I0000 00:00:1745009259.089700    1412 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 34487 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009259.106346    1415 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 34487 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009259.109184    1414 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 34487 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009259.113645    1417 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 34487 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# I0000 00:00:1745009259.118847    1409 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 34485 MB memory:  -> device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009265.500423    2878 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x361c72a0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009265.614120    2907 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x38d8f6c0
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009265.842344    2887 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x24c7c840
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009265.892986    2938 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x178a9e00
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745009265.915519    2918 cuda_solvers.cc:178] Creating GpuSolver handles for stream 0x196d7660
# processing windows:   0% 1/546 [00:29<4:25:02, 29.18s/batch]Processing batch 4/546
# processing windows:   0% 1/536 [00:30<4:30:42, 30.36s/batch]Processing batch 4/536
# processing windows:   0% 1/550 [00:28<4:17:32, 28.15s/batch]Processing batch 4/550
# processing windows:   0% 1/550 [00:29<4:25:37, 29.03s/batch]Processing batch 4/550
# processing windows:   0% 1/549 [00:30<4:39:57, 30.65s/batch]Processing batch 4/549
# processing windows:   0% 1/542 [00:31<4:40:47, 31.14s/batch]Processing batch 4/542
# processing windows:   0% 1/539 [00:31<4:44:20, 31.71s/batch]Processing batch 4/539
# processing windows:   0% 1/547 [00:31<4:50:53, 31.97s/batch]Processing batch 4/547
# processing windows:   0% 1/557 [00:32<4:58:58, 32.26s/batch]Processing batch 4/557
# processing windows:   0% 1/536 [00:33<4:58:41, 33.50s/batch]Processing batch 4/536
# processing windows:   0% 2/546 [00:52<3:54:05, 25.82s/batch]Processing batch 5/546
# processing windows:   0% 2/536 [00:55<4:03:44, 27.39s/batch]Processing batch 5/536
# processing windows:   0% 2/550 [00:52<3:59:16, 26.20s/batch]Processing batch 5/550
# processing windows:   0% 2/550 [00:52<3:57:55, 26.05s/batch]Processing batch 5/550
# processing windows:   0% 2/549 [00:54<4:04:55, 26.87s/batch]Processing batch 5/549
# processing windows:   0% 2/542 [00:54<4:00:24, 26.71s/batch]Processing batch 5/542
# processing windows:   0% 2/539 [00:55<4:00:10, 26.84s/batch]Processing batch 5/539
# processing windows:   0% 2/557 [00:55<4:09:32, 26.98s/batch]Processing batch 5/557
# processing windows:   0% 2/547 [00:55<4:06:10, 27.10s/batch]Processing batch 5/547
# processing windows:   0% 2/536 [00:56<4:03:56, 27.41s/batch]Processing batch 5/536
