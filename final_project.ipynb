# %% [markdown]
# ## Final Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project"
# Out:
# /content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project

# %%
# %pip install gpflow empyrical
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 2.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.9/392.9 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 8.2 MB/s eta 0:00:00
# ...
#   Created wheel for empyrical: filename=empyrical-0.5.5-py3-none-any.whl size=39753 sha256=11d6d93cb2f9aae5b40634fec641411bff96b92800f2e5e7395b2c33c58f306c
#   Stored in directory: /root/.cache/pip/wheels/ac/1d/58/a7ae5ef5c8de7c4b769f24c2584f4706564921f031b16b9cb6
# Successfully built empyrical
# ...

# %%
import multiprocessing
multiprocessing.cpu_count()
# Out:
# 8

# %%
# !python -m examples.concurent_cpd_quandl 21
# Out:
# Streaming output truncated to the last 5000 lines.
# processing windows:   9% 46/535 [11:39<2:04:15, 15.25s/batch]Processing batch 49/535
# processing windows:   4% 23/535 [05:45<2:06:30, 14.83s/batch]Processing batch 26/535
# processing windows:  13% 68/536 [17:09<1:52:52, 14.47s/batch]Processing batch 71/536
# processing windows:  22% 117/536 [29:30<1:43:15, 14.79s/batch]Processing batch 120/536
# processing windows:  24% 132/539 [33:06<1:57:14, 17.28s/batch]Processing batch 135/539
# processing windows:  19% 101/536 [25:30<1:45:50, 14.60s/batch]Processing batch 104/536
# processing windows:   9% 47/535 [11:53<2:00:38, 14.83s/batch]Processing batch 50/535
# processing windows:  17% 89/536 [22:25<1:57:11, 15.73s/batch]Processing batch 92/536
# processing windows:   4% 24/535 [05:59<2:05:48, 14.77s/batch]Processing batch 27/535
# processing windows:  22% 118/536 [29:45<1:43:12, 14.81s/batch]Processing batch 121/536
# ...
