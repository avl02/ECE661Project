# %% [markdown]
# ## Final Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project"
# Out:
# /content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project

# %%
# %pip install -q gpflow empyrical

# %%
# !python -m examples.concurrent_cpd_openbb 21
# Out:
# Resuming from previous run. Already processed 2 tickers
# Remaining tickers to process: 33
# Processing tickers:   0% 0/33 [00:00<?, ?it/s]Processing ticker 1/33: 6C
# 2025-04-21 15:05:37.825208: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745247937.846398   18315 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745247937.852487   18315 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-21 15:05:44.442840: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# No GPU found. Running on CPU
# Processing ticker 6C from 1990-01-01 to 2021-12-31
# LBW=21, batch size=10
# Resuming from previous run. Already processed 2023 time windows
# Processing with 4 workers
# Processing time windows:  93% 502/539 [49:08<06:04,  9.86s/batch]
