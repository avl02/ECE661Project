# %% [markdown]
# ## Final Project

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project"
# Out:
# /content/drive/MyDrive/Maestria/Duke/Clases/ECE 661 Deep Learning/final_project/ECE661Project

# %%
# %pip install -q gpflow empyrical
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 1.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 392.9/392.9 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.8/45.8 kB 3.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 8.3 MB/s eta 0:00:00
# ...

# %%
from settings.default import OPENBB_2003_TICKERS

tickers = OPENBB_2003_TICKERS[:7]
print(tickers)
# Out:
# ['6C', '6J', '6Z', 'AR', 'CC', 'CL', 'CT']

# %%
# !python -m examples.concurrent_cpd_openbb 21 10 --tickers AR
# Out:
# Resuming from previous run. Already processed 35 tickers
# Remaining tickers to process: 0
# All tickers have been processed. Nothing to do.
